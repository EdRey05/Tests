# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/EdRey05/Tests/main?labpath=Interactive_KMplots.ipynb)

# %% [markdown]
# # Interactive KM plots

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Install and import required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %% [markdown]
# ### Import datasets

# %% [markdown]
# Most files are .txt and some of them contain comments at the top with the symbol #.

# %%
#Read the clinical dataset and the RNA Seq files
df_clinical = pd.read_csv("data_clinical.txt",sep='\t', comment='#')
df_RNA = pd.read_csv("data_RNA.txt",sep='\t')

# %% [markdown]
# Preview the original datasets for reference of the changes needed.

# %%
print(df_clinical.shape)
df_clinical.head()

# %%
print(df_RNA.shape)
df_RNA.head()

# %% [markdown]
# Pre-process the clinical dataset first. It usually has a lot of information, and about half is not useful for the KM plots and we only need a pair of time column and a living/died column. However, we will let the user decide what is relevant. We will do the following adjustments to the dataset:
#
# 1. Re-order the columns to have at the beginning the relevant ones.
# 2. Get the pairs of time-status depending on what the user wants to plot (OS, RFS, PFS)
# 3. Sort alphabetically all the other columns and keep them for now, since there is no way to determine wait would be useful for the user.

# %%
#Prepare the variable with the reordered column names
clinical_columns_main = ["VITAL_STATUS"]

#Search for Overall Survival columns
if "OS_MONTHS" in df_clinical.columns and "OS_STATUS" in df_clinical.columns:
    clinical_columns_main.append("OS_MONTHS")
    clinical_columns_main.append("OS_STATUS")

#Search for Recurrence-Free Survival columns
if "RFS_MONTHS" in df_clinical.columns and "RFS_STATUS" in df_clinical.columns:
    clinical_columns_main.append("RFS_MONTHS")
    clinical_columns_main.append("RFS_STATUS")

#Search for Progression-Free Survival columns
if "PFS_MONTHS" in df_clinical.columns and "PFS_STATUS" in df_clinical.columns:
    clinical_columns_main.append("PFS_MONTHS")
    clinical_columns_main.append("PFS_STATUS")

#Order alphabetically the remaining columns
clinical_columns_extra = [col for col in df_clinical.columns if col not in clinical_columns_main]
clinical_columns_extra.sort()

#Apply the re-ordering to the df
clinical_columns_ordered = clinical_columns_main + clinical_columns_extra
df_clinical = df_clinical[clinical_columns_ordered]

# %% [markdown]
# Preview the edited clinical dataset

# %%
print(df_clinical.shape)
df_clinical.head()

# %% [markdown]
# ## A

# %% [markdown]
# # B
